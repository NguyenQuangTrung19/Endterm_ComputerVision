# %%
# !nvidia-smi
# Out:
# Thu Jun  5 14:14:39 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:00:04.0 Off |                    0 |
# | N/A   27C    P0             25W /  250W |       0MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /kaggle/working

# %% [markdown]
# ## Install dependencies

# %%
# !pip install -q ultralytics roboflow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 51.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.8/85.8 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 36.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 103.6 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 29.2 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 10.5 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.3 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 85.2 MB/s eta 0:00:00:00:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 3.6.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.3.2 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.40.1 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# bigframes 1.42.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# google-spark-connect 0.5.2 requires google-api-core>=2.19.1, but you have google-api-core 1.34.1 which is incompatible.
# google-cloud-bigtable 2.30.0 requires google-api-core[grpc]<3.0.0,>=2.16.0, but you have google-api-core 1.34.1 which is incompatible.
# google-cloud-storage 2.19.0 requires google-api-core<3.0.0dev,>=2.15.0, but you have google-api-core 1.34.1 which is incompatible.
# pandas-gbq 0.28.0 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.

# %% [markdown]
# ## Imports

# %%
from roboflow import Roboflow
from google.colab import userdata
from IPython.display import Image
from kaggle_secrets import UserSecretsClient
from IPython.display import Image

# %% [markdown]
# ## Pull dataset

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# ROBOFLOW_API_KEY = userdata.get('ROBOFLOW_API_KEY')
# rf = Roboflow(api_key=ROBOFLOW_API_KEY)

user_secrets = UserSecretsClient()
ROBOFLOW_API_KEY = user_secrets.get_secret("ROBOFLOW_API_KEY")

rf = Roboflow(api_key=ROBOFLOW_API_KEY)

project = rf.workspace("roboflow-jvuqo").project("football-field-detection-f07vi")
version = project.version(12)
dataset = version.download("yolov8")
# Out:
# /kaggle/working/datasets
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in football-field-detection-12 to yolov8:: 100%|██████████| 65802/65802 [00:04<00:00, 15820.44it/s]
# Extracting Dataset Version Zip to football-field-detection-12 in yolov8:: 100%|██████████| 564/564 [00:00<00:00, 3093.96it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# **NOTE:** Update `data.yaml` structure to align with the latest requirements of the `ultralytics` package.

# %% [markdown]
# ## Custom training

# %%
# %cd {HOME}

# !yolo task=pose mode=train model=yolov8x-pose.pt data={dataset.location}/data.yaml batch=16 epochs=100 imgsz=640 mosaic=0.0 plots=True
# Out:
# /kaggle/working
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8x-pose.pt to 'yolov8x-pose.pt'...
# 100%|████████████████████████████████████████| 133M/133M [00:09<00:00, 14.1MB/s]
# Ultralytics 8.3.150 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/datasets/football-field-detection-12/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8x-pose.pt, momentum=0.937, mosaic=0.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/pose/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=pose, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|█████████████████████████████████████████| 755k/755k [00:00<00:00, 167MB/s]
# Overriding model.yaml kpt_shape=[17, 3] with kpt_shape=[32, 3]
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#   8                  -1  3   6969600  ultralytics.nn.modules.block.C2f             [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.block.SPPF            [640, 640, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1948800  ultralytics.nn.modules.block.C2f             [960, 320, 3]
#  16                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   7174400  ultralytics.nn.modules.block.C2f             [960, 640, 3]
#  19                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  22        [15, 18, 21]  1  10379251  ultralytics.nn.modules.head.Pose             [1, [32, 3], [320, 640, 640]]
# YOLOv8x-pose summary: 224 layers, 69,813,891 parameters, 69,813,875 gradients, 265.4 GFLOPs
#
# Transferred 601/637 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|███████████████████████████████████████| 5.35M/5.35M [00:00<00:00, 293MB/s]
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3152.3±897.6 MB/s, size: 236.2 KB)
# train: Scanning /kaggle/working/datasets/football-field-detection-12/train/label
# train: New cache created: /kaggle/working/datasets/football-field-detection-12/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1376.9±993.9 MB/s, size: 231.5 KB)
# val: Scanning /kaggle/working/datasets/football-field-detection-12/valid/labels.
# val: New cache created: /kaggle/working/datasets/football-field-detection-12/valid/labels.cache
# Plotting labels to runs/pose/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 103 weight(decay=0.0), 113 weight(decay=0.0005), 112 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to runs/pose/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      14.9G      2.484      11.81     0.7061      4.018      2.562
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30       0.42      0.967      0.441      0.261          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      15.3G     0.9521      11.56     0.6981     0.7612       1.42
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30     0.0261      0.633     0.0234     0.0102          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      15.1G     0.8834       11.3     0.6513     0.6983      1.428
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30     0.0427          1     0.0482     0.0317          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      15.3G     0.7513      11.08     0.6223     0.6082      1.274
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          0          0          0          0          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       5/100        15G     0.7712      10.93     0.6027     0.6153      1.285
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          0          0          0          0          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      15.1G     0.9473      10.75     0.6011     0.7285      1.419
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          0          0          0          0          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      15.3G     0.8475      10.66     0.5943     0.6616      1.387
#                  Class     Images  Instances      Box(P          R      mAP50  m/usr/local/lib/python3.11/dist-packages/ultralytics/engine/validator.py:286: RuntimeWarning: invalid value encountered in greater_equal
#   matches = np.nonzero(iou >= threshold)  # IoU > threshold and classes match
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          0          0          0          0          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      15.1G     0.9139      10.42     0.5841     0.6706      1.511
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          0          0          0          0          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      15.3G      0.786      10.31     0.5948     0.5981      1.294
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          0          0          0          0          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      15.1G      0.692      10.25      0.595     0.5391      1.244
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.428      0.233      0.217     0.0395          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      15.3G     0.6584      9.954     0.5873     0.4897       1.19
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30    0.00541        0.1    0.00311   0.000404          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      15.1G     0.5837         10     0.5874     0.4492      1.133
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.613      0.333      0.355      0.118          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      15.3G     0.6975      9.903     0.5905     0.5499      1.238
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.712      0.833      0.802      0.238          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      14.5G     0.7082      10.06     0.5809     0.5184      1.236
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.642      0.767      0.793      0.288          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      14.8G     0.5592      9.658     0.5738     0.4253      1.137
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.687      0.733      0.703      0.506      0.041     0.0333    0.00524    0.00105
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      15.2G     0.5376      9.317     0.5808     0.4219      1.104
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.457      0.505      0.524      0.209          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      14.8G     0.5453      9.405     0.5704     0.4404       1.13
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.967       0.98      0.994      0.685          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      14.3G     0.5565      9.063     0.5645     0.4824      1.114
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.852      0.959      0.941      0.708          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      14.8G     0.5459      8.994     0.5657     0.4151      1.086
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.966          1      0.988      0.835          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      15.5G     0.5377      8.465     0.5518     0.4188       1.13
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.199      0.833      0.253      0.147     0.0469     0.0333    0.00844    0.00169
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      14.8G      0.585      8.675     0.5459     0.4194      1.135
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.724        0.9        0.9      0.706          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      22/100        15G     0.5479      9.169     0.5384     0.4174       1.11
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.958          1      0.993      0.716     0.0792     0.0333    0.00828    0.00164
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      15.3G     0.6186      8.817     0.5338     0.4498      1.154
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.779       0.82       0.82      0.684          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      15.1G     0.6141      8.591     0.5166     0.4347      1.129
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.895      0.851      0.914       0.74          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      15.3G     0.5396      8.073     0.5019     0.3928      1.107
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.935       0.96      0.986      0.739          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      15.5G     0.5304      8.199     0.4963     0.4053      1.111
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.934          1      0.992      0.831          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      15.3G     0.5288      8.332     0.4846     0.3892      1.104
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.968          1      0.994      0.807          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      15.1G     0.4736      8.042     0.4633     0.3687       1.05
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.556      0.467      0.455      0.304      0.177        0.1      0.038    0.00622
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      14.8G     0.4991      8.129     0.4636      0.397      1.089
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.812      0.863      0.879      0.618     0.0265     0.0333    0.00323   0.000323
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      30/100        15G     0.4167      7.809     0.4424     0.3531      1.035
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.951      0.933      0.987      0.837     0.0627     0.0667     0.0197    0.00448
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      15.3G       0.46      8.009     0.4403     0.3736      1.046
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.998      0.995      0.877          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      15.5G     0.4622      7.711     0.4274     0.3344      1.044
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.929          1      0.986      0.888      0.138        0.1     0.0386     0.0139
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      14.4G     0.4666        7.7      0.407     0.3607       1.05
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.919       0.99      0.822     0.0523     0.0333    0.00781   0.000781
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      15.1G     0.4425      6.757      0.381     0.3591      1.033
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.959      0.967      0.992      0.854          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      12.6G     0.4106      7.258     0.3802     0.3429      1.015
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.882      0.996      0.969      0.814      0.102        0.1     0.0227    0.00502
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      11.6G     0.4156      7.279     0.3848     0.3429      1.021
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.956        0.9       0.98      0.833        0.2      0.233     0.0678     0.0126
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      13.6G     0.4083      6.932     0.3655     0.3473      1.012
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.997      0.995      0.918          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      12.5G     0.4013      7.074      0.383     0.3486      1.015
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.959      0.933      0.987      0.864     0.0259     0.0333    0.00835    0.00236
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      13.5G     0.3909      6.721     0.3549     0.3378      1.007
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.983      0.967      0.991      0.912      0.203        0.2      0.116     0.0184
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      12.5G     0.4434      6.699     0.3474      0.362      1.025
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.964          1      0.994      0.862          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      12.8G     0.4068      6.538     0.3317     0.3223      1.021
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.993      0.967      0.993      0.945      0.103        0.1      0.055     0.0244
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      12.7G     0.4424      6.379     0.3346     0.3538      1.037
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.936          1      0.986       0.92      0.108        0.1     0.0365    0.00585
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      12.9G     0.3983       6.27     0.3146     0.3265     0.9899
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.992          1      0.995      0.889       0.46      0.467      0.263     0.0414
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      12.7G     0.3918      6.088      0.308     0.3164     0.9963
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.993          1      0.995      0.921      0.363      0.367      0.174     0.0333
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      13.1G     0.3788      5.784     0.3059     0.3107     0.9847
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.995      0.967       0.99      0.868     0.0595     0.0333     0.0117    0.00585
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      12.6G     0.3872      6.234     0.3133      0.324      1.006
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.997          1      0.995      0.929      0.107        0.1     0.0405     0.0135
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      12.9G      0.385      5.945     0.2857     0.3069      1.003
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.964      0.992      0.902      0.214        0.2      0.124      0.023
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      12.6G     0.3857      5.887     0.2823     0.3173     0.9956
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.935          1       0.99      0.913      0.455      0.433      0.357      0.135
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      13.6G     0.3566      5.587     0.2845     0.2972      1.001
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.934          1      0.989      0.922       0.54        0.5      0.429      0.114
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      12.5G     0.3683      5.276     0.2847     0.3066     0.9844
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.996          1      0.995      0.914      0.458        0.6      0.401      0.118
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      51/100        13G     0.3404      5.023     0.2562     0.2896     0.9682
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.999          1      0.995      0.926      0.288      0.297      0.172     0.0422
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      12.5G     0.3882      5.449     0.2795     0.3099     0.9834
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.998          1      0.995      0.911      0.465      0.467      0.302      0.078
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      13.3G     0.3932      5.494     0.2586     0.3075     0.9997
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.998          1      0.995      0.906      0.565      0.567      0.449     0.0953
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      12.6G     0.3681      5.008     0.2562     0.2903     0.9814
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.964      0.994      0.913       0.34      0.367      0.226     0.0455
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      12.7G     0.3712      4.775     0.2475     0.2905     0.9913
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.964          1      0.994      0.925      0.578        0.6      0.454       0.12
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      12.4G     0.4021      4.989     0.2549     0.3095     0.9831
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.997      0.995       0.92      0.566      0.566      0.416     0.0979
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      12.9G     0.3898      4.858     0.2392     0.3001     0.9846
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.999      0.995      0.921      0.185      0.167     0.0903     0.0198
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      11.6G     0.3612      5.142     0.2407      0.288     0.9677
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.999      0.995      0.933      0.433      0.433      0.292     0.0712
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      59/100        12G     0.3546      4.744     0.2405     0.2782     0.9605
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.999      0.995      0.925      0.378      0.367      0.263     0.0426
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      11.9G     0.3527      4.743     0.2494     0.2868      0.967
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.997      0.995       0.93      0.633      0.632      0.495      0.137
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      12.9G     0.3323      4.827      0.242     0.2696     0.9554
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.997      0.995      0.938        0.6      0.599      0.488      0.158
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      12.4G     0.3205      4.712     0.2381     0.2792     0.9738
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.995      0.995      0.931      0.699      0.695      0.584      0.157
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      13.8G     0.3268      4.703     0.2387     0.2851     0.9612
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.962      0.933      0.982      0.907      0.507      0.567      0.389     0.0946
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      12.8G     0.2895      4.321     0.2222       0.26     0.9657
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.998      0.933      0.992      0.944      0.558      0.589      0.445     0.0997
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      13.5G     0.3053      4.494     0.2239     0.2592     0.9513
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.999      0.995      0.947      0.566      0.567      0.473      0.137
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      12.5G     0.3181      4.678     0.2436     0.2582     0.9488
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.999          1      0.995      0.949      0.665      0.667      0.553      0.183
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      12.9G     0.3029      4.013     0.2239     0.2615     0.9581
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.993      0.995      0.958      0.698      0.694       0.67       0.21
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      12.2G     0.2965      4.159     0.2272     0.2594     0.9455
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.996      0.995      0.953      0.632       0.63      0.531      0.155
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      69/100        13G     0.3222      3.999     0.2268     0.2635     0.9558
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.968      0.997      0.993      0.945      0.611      0.633      0.482      0.151
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      12.3G     0.2942      4.178     0.2214     0.2604     0.9377
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.997      0.933      0.992      0.943      0.629      0.633      0.554      0.168
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      13.7G     0.2937      4.101     0.2142     0.2485     0.9316
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.997      0.933      0.991       0.93      0.629      0.633      0.513      0.169
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      12.5G      0.286      3.978     0.2134     0.2497     0.9349
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.991      0.995      0.957      0.798      0.792      0.729      0.196
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      12.2G     0.2864      3.647      0.207     0.2442     0.9363
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.995      0.995      0.938      0.832      0.828      0.764      0.226
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      11.8G     0.2967      3.889     0.2163     0.2505     0.9384
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.966      0.994      0.959      0.793      0.767      0.735      0.236
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      15.4G      0.294      3.839     0.2111      0.257     0.9408
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.965      0.993      0.946      0.758      0.732      0.652      0.241
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      12.9G     0.2779      3.687     0.2059     0.2454     0.9464
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.966      0.992      0.943      0.862      0.833      0.802      0.256
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      12.7G     0.2875      3.777     0.2109     0.2531     0.9263
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.966      0.993      0.943      0.793      0.767      0.688      0.217
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      13.1G     0.2612      3.599     0.2015     0.2465     0.9306
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.998      0.967       0.99      0.945      0.791      0.767      0.675       0.24
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      12.3G     0.2737      3.389     0.2066     0.2434     0.9331
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.998      0.967      0.993      0.936       0.86      0.833      0.781      0.291
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      11.9G     0.2717      3.508     0.2111     0.2452     0.9261
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.998      0.967      0.993      0.941       0.86      0.833      0.786      0.279
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      13.2G     0.2701      3.326     0.2039     0.2399     0.9242
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.998      0.995      0.949      0.866      0.865      0.802      0.259
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      12.2G     0.2654      3.346     0.2074     0.2474     0.9108
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.998      0.967      0.994      0.921      0.826        0.8      0.713      0.211
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      13.5G     0.2836      3.529     0.2082     0.2485     0.9243
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.998      0.967      0.993      0.941      0.688      0.667      0.577      0.191
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      84/100        13G     0.2879      3.538     0.2064     0.2506     0.9215
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.997      0.995      0.936      0.826        0.8      0.763      0.238
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      12.6G     0.2764      3.466     0.2023     0.2424     0.9306
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.998      0.995      0.934        0.8      0.798      0.767      0.282
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      12.5G     0.2521      3.045      0.201     0.2349     0.9104
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.998      0.995      0.943      0.933      0.932      0.951      0.338
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      87/100        13G     0.2466      3.264     0.1915     0.2274     0.9366
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.999      0.967      0.992      0.933      0.792      0.767      0.763      0.287
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      12.8G     0.2651      3.192     0.1935     0.2335     0.9053
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.997      0.995      0.957      0.866      0.864      0.821      0.319
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      12.2G     0.2566      3.056     0.2032     0.2297     0.9204
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.999      0.995      0.953      0.933      0.933      0.915      0.397
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      90/100        13G     0.2512      2.973     0.2017     0.2314     0.9105
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.998          1      0.995      0.942      0.931      0.933      0.913      0.316
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      91/100        13G     0.2494      3.129     0.1976     0.2293     0.9108
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.998          1      0.995      0.942      0.865      0.867      0.805       0.29
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      12.5G     0.2526       2.83     0.1963     0.2304     0.9131
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.999          1      0.995      0.945      0.866      0.867      0.847      0.323
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      13.9G     0.2475      2.987     0.2001     0.2166     0.9375
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.999          1      0.995      0.952      0.899        0.9      0.852      0.331
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      12.6G     0.2417      3.013     0.1949     0.2182     0.9176
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30      0.999          1      0.995      0.948      0.932      0.933      0.895      0.391
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      12.8G     0.2584      2.911     0.1968     0.2352     0.9233
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.999      0.995      0.952      0.933      0.932      0.906      0.403
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      11.9G     0.2414      2.797      0.196      0.227     0.9093
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.998      0.995      0.952          1      0.998      0.995       0.39
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      12.5G     0.2573      2.786     0.1985     0.2284     0.8963
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.998      0.995      0.957      0.967      0.965      0.946      0.396
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      12.1G     0.2519      2.789     0.2001     0.2228     0.9246
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.998      0.995      0.948      0.933      0.932      0.895      0.416
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      99/100        13G     0.2405      2.589     0.1972     0.2222     0.9151
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.998      0.995      0.945      0.933      0.931      0.898      0.424
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      12.1G      0.235      2.683     0.1941     0.2185     0.9112
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         30         30          1      0.998      0.995      0.949          1      0.998      0.995      0.467
#
# 100 epochs completed in 0.640 hours.
# Optimizer stripped from runs/pose/train/weights/last.pt, 140.0MB
# Optimizer stripped from runs/pose/train/weights/best.pt, 140.0MB
#
# Validating runs/pose/train/weights/best.pt...
# Ultralytics 8.3.150 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLOv8x-pose summary (fused): 121 layers, 69,784,275 parameters, 0 gradients, 264.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
#                    all         30         30          1      0.998      0.995      0.949          1      0.998      0.995      0.467
# Speed: 0.1ms preprocess, 15.8ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to runs/pose/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# !zip -r {HOME}/results.zip {HOME}/runs/pose/train
# Out:
#   adding: kaggle/working/runs/pose/train/ (stored 0%)
#   adding: kaggle/working/runs/pose/train/train_batch1261.jpg (deflated 13%)
#   adding: kaggle/working/runs/pose/train/BoxPR_curve.png (deflated 30%)
#   adding: kaggle/working/runs/pose/train/train_batch0.jpg (deflated 13%)
#   adding: kaggle/working/runs/pose/train/confusion_matrix_normalized.png (deflated 37%)
#   adding: kaggle/working/runs/pose/train/val_batch0_pred.jpg (deflated 6%)
#   adding: kaggle/working/runs/pose/train/labels.jpg (deflated 57%)
#   adding: kaggle/working/runs/pose/train/train_batch1260.jpg (deflated 8%)
#   adding: kaggle/working/runs/pose/train/labels_correlogram.jpg (deflated 53%)
#   adding: kaggle/working/runs/pose/train/train_batch1.jpg (deflated 12%)
#   adding: kaggle/working/runs/pose/train/PoseR_curve.png (deflated 18%)
#   adding: kaggle/working/runs/pose/train/train_batch1262.jpg (deflated 10%)
#   adding: kaggle/working/runs/pose/train/val_batch0_labels.jpg (deflated 7%)
#   adding: kaggle/working/runs/pose/train/BoxF1_curve.png (deflated 19%)
#   adding: kaggle/working/runs/pose/train/train_batch2.jpg (deflated 11%)
#   adding: kaggle/working/runs/pose/train/results.png (deflated 7%)
#   adding: kaggle/working/runs/pose/train/weights/ (stored 0%)
#   adding: kaggle/working/runs/pose/train/weights/best.pt (deflated 8%)
#   adding: kaggle/working/runs/pose/train/weights/last.pt (deflated 8%)
#   adding: kaggle/working/runs/pose/train/results.csv (deflated 61%)
#   adding: kaggle/working/runs/pose/train/PoseF1_curve.png (deflated 19%)
#   adding: kaggle/working/runs/pose/train/args.yaml (deflated 52%)
#   adding: kaggle/working/runs/pose/train/PoseP_curve.png (deflated 27%)
#   adding: kaggle/working/runs/pose/train/confusion_matrix.png (deflated 40%)
#   adding: kaggle/working/runs/pose/train/PosePR_curve.png (deflated 30%)
#   adding: kaggle/working/runs/pose/train/BoxP_curve.png (deflated 27%)
#   adding: kaggle/working/runs/pose/train/BoxR_curve.png (deflated 18%)

# %% [markdown]
# ## Validate custom model

# %%
# %cd {HOME}

# !yolo task=pose mode=val model={HOME}/runs/pose/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /kaggle/working
# Ultralytics 8.3.150 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLOv8x-pose summary (fused): 121 layers, 69,784,275 parameters, 0 gradients, 264.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3229.2±741.7 MB/s, size: 238.8 KB)
# val: Scanning /kaggle/working/datasets/football-field-detection-12/valid/labels.
#                  Class     Images  Instances      Box(P          R      mAP50  m
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
#                    all         30         30          1      0.998      0.995      0.949          1      0.998      0.995       0.47
# Speed: 1.8ms preprocess, 17.2ms inference, 0.0ms loss, 10.6ms postprocess per image
# Results saved to runs/pose/val2
# 💡 Learn more at https://docs.ultralytics.com/modes/val
